# %%
import os
from datetime import datetime
import pandas as pd
from progressbar import progressbar
import subprocess
from multiprocessing.pool import ThreadPool

# %%
def num_lines(file):
    r = 0
    with open(file, 'r') as file:
        for l in file:
            r += 1
            
    return r

# %%
def epoch_to_datetime(d):
    return datetime.fromtimestamp(d)

# %%
base_folder = 'dataset/iot_23_datasets_full/opt/Malware-Project/BigDataset/IoTScenarios/'
destination_folder = 'dataset/parsed/'

# %%
def count_parsed_files():
    return len(os.listdir(destination_folder))

# %%
folders = [base_folder + i for i in os.listdir(base_folder)]

# %%
files = [i + '/bro/' + os.listdir(i + '/bro')[0] for i in folders if 'Honeypot-Capture-7-1' not in i] + ['dataset/iot_23_datasets_full/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled']

# %%
class FileParser:
    def __init__(self, file_path, batch_size=100000, verbose=False):
        self.file_path = file_path
        self.num_lines = num_lines(file_path)
        self.batch_size = batch_size
        self.aux_df = pd.DataFrame()
        self.files_generated = 0
        self.verbose = verbose

    def _parse_line(self, line):
        return line.replace('\t', ' ').split()

    def parse_fields(self, fields_line):
        self.columns = self._parse_line(fields_line)[1:]

    def parse_types(self, types_line):
        self.types = self._parse_line(types_line)[1:]
    
    def _append_line(self, line):
        aux = pd.DataFrame(self._parse_line(line)).T
        aux.columns = self.columns
        self.aux_df = self.aux_df.append(aux)
        if len(self.aux_df) > self.batch_size:
            self._rotate_df()
    
    def _rotate_df(self):
        part_name = destination_folder + f'part_{count_parsed_files() + 1}'
        if self.verbose:
            print('Rotating df; file saved =', part_name)
        
        self.aux_df.to_parquet(part_name)
        self.files_generated += 1
        self.aux_df = pd.DataFrame()
    
    def process(self):
        if self.verbose:
            print('starting processing of file:', self.file_path)
            
        with open(self.file_path, 'r') as file:
            for line in progressbar(file, max_value=self.num_lines, redirect_stdout=True):
                if line.startswith('#fields'):
                    self.parse_fields(line)
                elif line.startswith('#types'):
                    self.parse_types(line)
                elif not line.startswith('#'):
                    self._append_line(line)
        
        if len(self.aux_df) > 0:
            self._rotate_df()
        
        return self.files_generated

# %%
def process_file(file):
    parser = FileParser(file, verbose=True)
    return parser.process()

# %%
lines = []
columns = []
with open(files[0], 'r') as file:
    for i in range(50):
        l = file.readline()
        if l.startswith('#fields'):
            columns = l.replace('\t', ' ').split()[1:]
        elif not l.startswith('#'):
            lines.append(l.replace('\t', ' ').split())

# %%
pd.DataFrame(lines, columns=columns)
# Out:
#                    ts                 uid      id.orig_h id.orig_p  \
# 0   1540469302.538640  CGm6jB4dXK71ZDWUDh  192.168.1.132     58687
# 1   1540469197.400159  CnaDAG3n5r8eiG4su2  192.168.1.132      1900
# 2   1540469385.734089  CUrxU238nt0m6yTgKf  192.168.1.132     32893
# 3   1540469831.302625  CGQf8t1kjdxB5PHXL4  192.168.1.132     53395
# 4   1540469831.265405  CUo9DH2QDnCaBIGjkg  192.168.1.132     52801
# 5   1540469418.379528  CAvXOZ3htimWEtglii  192.168.1.132      1900
# 2      216.239.35.8       123   udp       -     0.016986         48  ...
# 3        2.16.60.82       443   tcp       -     0.003497          0  ...
# 4       192.168.1.1        53   udp     dns     0.036724         34  ...
# 5   239.255.255.250      1900   udp       -   384.518261      15072  ...
# 6     216.239.35.12       123   udp       -     0.270332         48  ...
# 7      216.239.35.0       123   udp       -     0.111429         48  ...
# 8      216.239.35.4       123   udp       -     0.114433         48  ...
# 9      216.239.35.8       123   udp       -     0.016984         48  ...
# 10       2.16.60.82       443   tcp       -     0.003497          0  ...
# 11      192.168.1.1        53   udp     dns     0.040227         34  ...
# 12    216.239.35.12       123   udp       -     0.270346         48  ...
# 13     216.239.35.0       123   udp       -     0.109684         48  ...
# 14     216.239.35.4       123   udp       -     0.114426         48  ...
# 15     216.239.35.8       123   udp       -     0.016980         48  ...
# 16  239.255.255.250      1900   udp       -  1633.044330      60288  ...
# 17      2.16.60.139       443   tcp       -     0.003498          0  ...
# 18      192.168.1.1        53   udp     dns     0.183145         34  ...
# 19    216.239.35.12       123   udp       -     0.272344         48  ...
# 20     216.239.35.0       123   udp       -     0.109436         48  ...
# 21  239.255.255.250      1900   udp       -   766.048560      28260  ...
# 22  239.255.255.250      1900   udp       -    50.851218       3768  ...
# 23    52.209.221.67        80   tcp    http     0.088446       1847  ...
# 24    52.215.95.120        80   tcp    http     0.109187       1847  ...
# 25      192.168.1.1        53   udp     dns     0.050455         37  ...
# 26      192.168.1.1        53   udp     dns     0.003998         37  ...
# 27      192.168.1.1        53   udp     dns     0.000499         37  ...
# 28      192.168.1.1        53   udp     dns     0.000500         37  ...
# 29       2.16.60.82       443   tcp       -     0.003499          0  ...
# 30      192.168.1.1        53   udp     dns     0.046210         34  ...
# 31     216.239.35.4       123   udp       -     0.114417         48  ...
# 32     216.239.35.8       123   udp       -     0.017238         48  ...
# 33  239.255.255.250      1900   udp       -    50.868027       3768  ...
# 34    216.239.35.12       123   udp       -     0.269349         48  ...
# 35      2.16.60.139       443   tcp       -     0.003495          0  ...
# 36      192.168.1.1        53   udp     dns     0.036214         34  ...
# 37  239.255.255.250      1900   udp       -  1480.810378      52752  ...
# 38       2.16.60.82       443   tcp       -     0.003496          0  ...
# 39      192.168.1.1        53   udp     dns     0.200137         34  ...
# 40     216.239.35.0       123   udp       -     0.109694         48  ...
# 41     216.239.35.4       123   udp       -     0.116179         48  ...
#
#    local_resp missed_bytes    history orig_pkts orig_ip_bytes resp_pkts  \
# 0           -            0         Dd         1            76         1
# 1           -            0          D        24          8208         0
# 2           -            0         Dd         1            76         1
# 3           -            0      ShAFf         5           212         3
# 4           -            0         Dd         1            62         1
# 5           -            0          D        48         16416         0
# 6           -            0         Dd         1            76         1
# 7           -            0         Dd         1            76         1
# 8           -            0         Dd         1            76         1
# 9           -            0         Dd         1            76         1
# 10          -            0      ShAFf         4           172         2
# 11          -            0         Dd         1            62         1
# 12          -            0         Dd         1            76         1
# 13          -            0         Dd         1            76         1
# 14          -            0         Dd         1            76         1
# 15          -            0         Dd         1            76         1
# 16          -            0          D       192         65664         0
# 17          -            0      ShAFf         4           172         2
# 18          -            0         Dd         1            62         1
# 19          -            0         Dd         1            76         1
# 20          -            0         Dd         1            76         1
# 21          -            0          D        90         30780         0
# 22          -            0          D        12          4104         0
# 23          -            0  ShADadtfF         7          2139         7
# 24          -            0   ShADadfF         6          2099         6
# 25          -            0         Dd         1            65         1
# 26          -            0         Dd         1            65         1
# 27          -            0         Dd         1            65         1
# 28          -            0         Dd         1            65         1
# 29          -            0     ShAFaf         4           172         3
# 30          -            0         Dd         1            62         1
# 31          -            0         Dd         1            76         1
# 32          -            0         Dd         1            76         1
# 33          -            0          D        12          4104         0
# 34          -            0         Dd         1            76         1
# 35          -            0      ShAFf         5           212         3
# 36          -            0         Dd         1            62         1
# 37          -            0          D       168         57456         0
# 38          -            0      ShAFf         4           172         2
# 39          -            0         Dd         1            62         1
# 40          -            0         Dd         1            76         1
# 41          -            0         Dd         1            76         1
#
#    resp_ip_bytes tunnel_parents   label detailed-label
# 0             76              -  benign              -
# 1              0              -  benign              -
# 2             76              -  benign              -
# 3            144              -  benign              -
# 4            339              -  benign              -
# 5              0              -  benign              -
# 6             76              -  benign              -
# 7             76              -  benign              -
# 8             76              -  benign              -
# 9             76              -  benign              -
# 10            92              -  benign              -
# 11           339              -  benign              -
# 12            76              -  benign              -
# 13            76              -  benign              -
# 14            76              -  benign              -
# 15            76              -  benign              -
# 16             0              -  benign              -
# 17            92              -  benign              -
# 18           339              -  benign              -
# 19            76              -  benign              -
# 20            76              -  benign              -
# 21             0              -  benign              -
# 22             0              -  benign              -
# 23          1823              -  benign              -
# 24          1035              -  benign              -
# 25           207              -  benign              -
# 26           470              -  benign              -
# 27           128              -  benign              -
# 28           160              -  benign              -
# 29           132              -  benign              -
# 30           325              -  benign              -
# 31            76              -  benign              -
# 32            76              -  benign              -
# 33             0              -  benign              -
# 34            76              -  benign              -
# 35           144              -  benign              -
# 36           339              -  benign              -
# 37             0              -  benign              -
# 38            92              -  benign              -
# 39           325              -  benign              -
# 40            76              -  benign              -
# 41            76              -  benign              -
#
# [42 rows x 23 columns]

# %%
for file in files:
    r = process_file(file)
    print(f'parts created for file: {r}')
# Out:
# starting processing of file: dataset/iot_23_datasets_full/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled
# 100% (461 of 461) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
# Rotating df; file saved = dataset/parsed/part_1
# parts created for file: 1
# starting processing of file: dataset/iot_23_datasets_full/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled
# 100% (1383 of 1383) |####################| Elapsed Time: 0:00:01 Time:  0:00:01
# Rotating df; file saved = dataset/parsed/part_2
# parts created for file: 1
# starting processing of file: dataset/iot_23_datasets_full/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled
#   2% (26451 of 1008757) |                | Elapsed Time: 0:02:18 ETA:   3:01:43
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-60a809575c57> in <module>
#       1 for file in files:
# ----> 2     r = process_file(file)
#       3     print(f'parts created for file: {r}')
#
# <ipython-input-30-6371b41dc93a> in process_file(file)
#       1 def process_file(file):
#       2     parser = FileParser(file, verbose=True)
# ----> 3     return parser.process()
#
# <ipython-input-29-43d3e3fc6255> in process(self)
#      38
#      39         with open(self.file_path, 'r') as file:
# ---> 40             for line in progressbar(file, max_value=self.num_lines, redirect_stdout=True):
#      41                 if line.startswith('#fields'):
#      42                     self.parse_fields(line)
#
# ~\anaconda3\lib\site-packages\progressbar\shortcuts.py in progressbar(iterator, min_value, max_value, widgets, prefix, suffix, **kwargs)
#       8         widgets=widgets, prefix=prefix, suffix=suffix, **kwargs)
#       9
# ---> 10     for result in progressbar(iterator):
#      11         yield result
#
# ~\anaconda3\lib\site-packages\progressbar\bar.py in __next__(self)
#     549                 self.start()
#     550             else:
# --> 551                 self.update(self.value + 1)
#     552             return value
#     553         except StopIteration:
#
# ~\anaconda3\lib\site-packages\progressbar\bar.py in update(self, value, force, **kwargs)
#     684             ResizableMixin.update(self, value=value)
#     685             ProgressBarBase.update(self, value=value)
# --> 686             StdRedirectMixin.update(self, value=value)
#     687
#     688             # Only flush if something was actually written
#
# ~\anaconda3\lib\site-packages\progressbar\bar.py in update(self, value)
#     184             self.fd.write('\r' + ' ' * self.term_width + '\r')
#     185
# --> 186         utils.streams.flush()
#     187         DefaultFdMixin.update(self, value=value)
#     188
#
# ~\anaconda3\lib\site-packages\progressbar\utils.py in flush(self)
#     337         if self.wrapped_stdout:  # pragma: no branch
#     338             try:
# --> 339                 self.stdout._flush()
#     340             except (io.UnsupportedOperation,
#     341                     AttributeError):  # pragma: no cover
#
# ~\anaconda3\lib\site-packages\progressbar\utils.py in _flush(self)
#     217
#     218         # when explicitly flushing, always flush the target as well
# --> 219         self.flush_target()
#     220
#     221     def flush_target(self):  # pragma: no cover
#
# ~\anaconda3\lib\site-packages\progressbar\utils.py in flush_target(self)
#     221     def flush_target(self):  # pragma: no cover
#     222         if not self.target.closed and getattr(self.target, 'flush'):
# --> 223             self.target.flush()
#     224
#     225
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in flush(self)
#     342         if self.pub_thread and self.pub_thread.thread is not None and self.pub_thread.thread.is_alive():
#     343             # request flush on the background thread
# --> 344             self.pub_thread.schedule(self._flush)
#     345             # wait for flush to actually get through, if we can.
#     346             # waiting across threads during import can cause deadlocks
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     489                                  copy_threshold=self.copy_threshold)
#     490             data.group = group
# --> 491         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     492
#     493     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
